# %%
def process(opcode,num1pos,num2pos,outpos):
    #print(opcode,num1pos,num2pos,outpos)
    try:
        if(opcode==1):
            #print("sum:",l[num1pos]+l[num2pos]," = ",l[num1pos],"+",l[num2pos])
            l[outpos]=l[num1pos]+l[num2pos]
            return(1)
        elif(opcode==2):
            #print("product:",l[num1pos]*l[num2pos]," = ",l[num1pos],"*",l[num2pos])
            l[outpos]=l[num1pos]*l[num2pos]
            return(1)
        elif(opcode==99):
            #print("Found 99",opcode," exit program")
            return(-1)
        else:
            #print("Found something else: ",opcode," continue next")
            return(1)
    except:
        return(-1)


def program(l,noun,verb):
    l[1]=noun
    l[2]=verb
    counter=0
    for i in range(len(l)):
        #print(l)
        #print("counter:",counter)
        val=process(l[counter],l[counter+1],l[counter+2],l[counter+3])
        #print(val)
        if(val==1):
            #print("inside val")
            counter=counter+4
        else:
            break
    #print(noun, verb, l[0])
    return(l[0])
l=[1,0,0,3,1,1,2,3,1,3,4,3,1,5,0,3,2,1,9,19,1,19,5,23,2,6,23,27,1,6,27,31,2,31,9,35,1,35,6,39,1,10,39,43,2,9,43,47,1,5,47,51,2,51,6,55,1,5,55,59,2,13,59,63,1,63,5,67,2,67,13,71,1,71,9,75,1,75,6,79,2,79,6,83,1,83,5,87,2,87,9,91,2,9,91,95,1,5,95,99,2,99,13,103,1,103,5,107,1,2,107,111,1,111,5,0,99,2,14,0,0]
print(program(l,12,2))
# Out:
# 3166704

# %%
desired_output = 19690720
l=[1,0,0,3,1,1,2,3,1,3,4,3,1,5,0,3,2,1,9,19,1,19,5,23,2,6,23,27,1,6,27,31,2,31,9,35,1,35,6,39,1,10,39,43,2,9,43,47,1,5,47,51,2,51,6,55,1,5,55,59,2,13,59,63,1,63,5,67,2,67,13,71,1,71,9,75,1,75,6,79,2,79,6,83,1,83,5,87,2,87,9,91,2,9,91,95,1,5,95,99,2,99,13,103,1,103,5,107,1,2,107,111,1,111,5,0,99,2,14,0,0]
print("hello")
print(program(l,12,2))
for i in range(100):
    for j in range(100):
        l=[1,0,0,3,1,1,2,3,1,3,4,3,1,5,0,3,2,1,9,19,1,19,5,23,2,6,23,27,1,6,27,31,2,31,9,35,1,35,6,39,1,10,39,43,2,9,43,47,1,5,47,51,2,51,6,55,1,5,55,59,2,13,59,63,1,63,5,67,2,67,13,71,1,71,9,75,1,75,6,79,2,79,6,83,1,83,5,87,2,87,9,91,2,9,91,95,1,5,95,99,2,99,13,103,1,103,5,107,1,2,107,111,1,111,5,0,99,2,14,0,0]
        result = program(l,i,j)
        print("program(",i,",",j,") = ",result)
        if(result == desired_output):
            exit()
# Out:
# hello
# 3166704
# program( 0 , 0 ) =  250702
# program( 0 , 1 ) =  250703
# program( 0 , 2 ) =  250704
# program( 0 , 3 ) =  250705
# program( 0 , 4 ) =  250706
# program( 0 , 5 ) =  250707
# program( 0 , 6 ) =  250708
# program( 0 , 7 ) =  250709
# program( 0 , 8 ) =  250710
# program( 0 , 9 ) =  250711
# program( 0 , 10 ) =  250712
# program( 0 , 11 ) =  250713
# program( 0 , 12 ) =  250714
# program( 0 , 13 ) =  250715
# program( 0 , 14 ) =  250716
# program( 0 , 15 ) =  250717
# program( 0 , 16 ) =  250718
# program( 0 , 17 ) =  250719
# program( 0 , 18 ) =  250720
# program( 0 , 19 ) =  250721
# program( 0 , 20 ) =  250722
# program( 0 , 21 ) =  250723
# program( 0 , 22 ) =  250724
# program( 0 , 23 ) =  250725
# program( 0 , 24 ) =  250726
# program( 0 , 25 ) =  250727
# program( 0 , 26 ) =  250728
# program( 0 , 27 ) =  250729
# program( 0 , 28 ) =  250730
# program( 0 , 29 ) =  250731
# program( 0 , 30 ) =  250732
# program( 0 , 31 ) =  250733
# program( 0 , 32 ) =  250734
# ...
